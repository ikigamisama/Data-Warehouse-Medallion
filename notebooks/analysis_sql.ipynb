# %% [markdown]
# # SQL Data Analysis from Data Warehouse

# %%
import os
import boto3
import duckdb

# %% [markdown]
# ## Download the Data from the s3 source
#
# ### **Note**: You must acctive the dag analytics_warehouse_sql_dag before you download it from s3

# %%
if not os.path.exists('business_analytics.db'):
    s3 = boto3.client(
        service_name="s3",
        endpoint_url="http://localhost:9000",
        aws_access_key_id="minioLocalAccessKey",
        aws_secret_access_key="minioLocalSecretKey123",
        region_name="us-east-1",
    )

    s3.download_file(
        Bucket='business-analytics-sql',
        Key='warehouse/business_analytics.db',
        Filename='business_analytics.db'
    )

con = duckdb.connect(database='business_analytics.db')

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### 1. Database Exploration
#
# This is the first step in any data analysis process. It involves getting familiar with the structure and contents of your database. You check which tables exist, what types of data they hold, how they're connected, and whether there are missing or duplicate values.
# The goal is to understand the "shape" of your data before diving into deeper analysis.

# %%
schema_list = con.execute("SELECT table_schema, table_name FROM information_schema.tables").df()
schema_list
# Out:
#    table_schema          table_name
# 0        bronze             cat_erp
# 1        bronze            cust_erp
# 2        bronze           cust_info
# 3        bronze             loc_erp
# 4        bronze            prd_info
# 5        bronze  sales_details_info
# 6        silver       crm_cust_info
# 7        silver        crm_prd_info
# 8        silver   crm_sales_details
# 9        silver            erp_cust
# 10       silver             erp_loc
# 11       silver          erp_px_cat
# 12         gold       dim_customers
# 13         gold        dim_products
# 14         gold          fact_sales

# %%
column_list = con.execute("SELECT * FROM information_schema.columns WHERE table_name = 'dim_customers'").df()
column_list
# Out:
#          table_catalog table_schema     table_name      column_name  \
# 0   business_analytics         gold  dim_customers     customer_key
# 1   business_analytics         gold  dim_customers      customer_id
# 2   business_analytics         gold  dim_customers  customer_number
# 3   business_analytics         gold  dim_customers       first_name
# 4   business_analytics         gold  dim_customers        last_name
# 5   business_analytics         gold  dim_customers          country
# 6   business_analytics         gold  dim_customers   marital_status
# 7   business_analytics         gold  dim_customers           gender
# 8   business_analytics         gold  dim_customers        birthdate
# 9   business_analytics         gold  dim_customers      create_date
# 10  business_analytics         gold  dim_customers  dwh_create_date
#
#     ordinal_position column_default is_nullable  data_type  \
# 0                  1           None         YES     BIGINT
# 1                  2           None         YES    INTEGER
# 2                  3           None         YES    VARCHAR
# 3                  4           None         YES    VARCHAR
# 4                  5           None         YES    VARCHAR
# 5                  6           None         YES    VARCHAR
# 6                  7           None         YES    VARCHAR
# 7                  8           None         YES    VARCHAR
# 8                  9           None         YES       DATE
# 9                 10           None         YES       DATE
# 10                11           None         YES  TIMESTAMP
#
#     character_maximum_length  character_octet_length  ...  \
# 0                       <NA>                    <NA>  ...
# 1                       <NA>                    <NA>  ...
# 2                       <NA>                    <NA>  ...
# 3                       <NA>                    <NA>  ...
# 4                       <NA>                    <NA>  ...
# 5                       <NA>                    <NA>  ...
# 6                       <NA>                    <NA>  ...
# 7                       <NA>                    <NA>  ...
# 8                       <NA>                    <NA>  ...
# 9                       <NA>                    <NA>  ...
# 10                      <NA>                    <NA>  ...
#
#     identity_generation  identity_start  identity_increment  identity_maximum  \
# 0                  None            None                None              None
# 1                  None            None                None              None
# 2                  None            None                None              None
# 3                  None            None                None              None
# 4                  None            None                None              None
# 5                  None            None                None              None
# 6                  None            None                None              None
# 7                  None            None                None              None
# 8                  None            None                None              None
# 9                  None            None                None              None
# 10                 None            None                None              None
#
#    identity_minimum  identity_cycle is_generated generation_expression  \
# 0              None            <NA>         None                  None
# 1              None            <NA>         None                  None
# 2              None            <NA>         None                  None
# 3              None            <NA>         None                  None
# 4              None            <NA>         None                  None
# 5              None            <NA>         None                  None
# 6              None            <NA>         None                  None
# 7              None            <NA>         None                  None
# 8              None            <NA>         None                  None
# 9              None            <NA>         None                  None
# 10             None            <NA>         None                  None
#
#    is_updatable COLUMN_COMMENT
# 0          <NA>           None
# 1          <NA>           None
# 2          <NA>           None
# 3          <NA>           None
# 4          <NA>           None
# 5          <NA>           None
# 6          <NA>           None
# 7          <NA>           None
# 8          <NA>           None
# 9          <NA>           None
# 10         <NA>           None
#
# [11 rows x 45 columns]

# %%
gold_dim_customers = con.execute("SELECT * FROM gold.dim_customers").df()
gold_dim_customers
# Out:
#        customer_key  customer_id customer_number first_name last_name  \
# 0                 1        11000      AW00011000        Jon      Yang
# 1                 2        11001      AW00011001     Eugene     Huang
# 2                 3        11002      AW00011002      Ruben    Torres
# 3                 4        11003      AW00011003    Christy       Zhu
# 4                 5        11004      AW00011004  Elizabeth   Johnson
# ...             ...          ...             ...        ...       ...
# 18479         18480        29479      AW00029479      Tommy      Tang
# 18480         18481        29480      AW00029480       Nina      Raji
# 18481         18482        29481      AW00029481       Ivan      Suri
# 18482         18483        29482      AW00029482    Clayton     Zhang
# 18483         18484        29483      AW00029483       Marc   Navarro
#
#               country marital_status  gender  birthdate create_date  \
# 0           Australia        Married    Male 1971-10-06  2025-10-06
# 1           Australia         Single    Male 1976-05-10  2025-10-06
# 2           Australia        Married    Male 1971-02-09  2025-10-06
# 3           Australia         Single  Female 1973-08-14  2025-10-06
# 4           Australia         Single  Female 1979-08-05  2025-10-06
# ...               ...            ...     ...        ...         ...
# 18479          France        Married     n/a 1969-06-30  2026-01-25
# 18480  United Kingdom         Single     n/a 1977-05-06  2026-01-25
# 18481         Germany         Single     n/a 1965-07-04  2026-01-25
# 18482          France        Married     n/a 1964-09-01  2026-01-25
# 18483          France        Married     n/a 1965-06-06  2026-01-27
#
#               dwh_create_date
# 0     2025-05-25 15:28:04.496
# 1     2025-05-25 15:28:04.496
# 2     2025-05-25 15:28:04.496
# 3     2025-05-25 15:28:04.496
# 4     2025-05-25 15:28:04.496
# ...                       ...
# 18479 2025-05-25 15:28:04.496
# 18480 2025-05-25 15:28:04.496
# 18481 2025-05-25 15:28:04.496
# 18482 2025-05-25 15:28:04.496
# 18483 2025-05-25 15:28:04.496
#
# [18484 rows x 11 columns]

# %%
gold_dim_products = con.execute("SELECT * FROM gold.dim_products").df()
gold_dim_products
# Out:
#      product_key  product_id product_number               product_name  \
# 0              1         210     FR-R92B-58  HL Road Frame - Black- 58
# 1              2         211     FR-R92R-58    HL Road Frame - Red- 58
# 2              3         348     BK-M82B-38     Mountain-100 Black- 38
# 3              4         349     BK-M82B-42     Mountain-100 Black- 42
# 4              5         350     BK-M82B-44     Mountain-100 Black- 44
# ..           ...         ...            ...                        ...
# 290          291         530        TT-T092          Touring Tire Tube
# 291          292         473      VE-C304-L            Classic Vest- L
# 292          293         472      VE-C304-M            Classic Vest- M
# 293          294         471      VE-C304-S            Classic Vest- S
# 294          295         477        WB-H098      Water Bottle - 30 oz.
#
#     category_id     category        subcategory maintenance  cost  \
# 0         CO_RF   Components        Road Frames        true     0
# 1         CO_RF   Components        Road Frames        true     0
# 2         BI_MB        Bikes     Mountain Bikes        true  1898
# 3         BI_MB        Bikes     Mountain Bikes        true  1898
# 4         BI_MB        Bikes     Mountain Bikes        true  1898
# ..          ...          ...                ...         ...   ...
# 290       AC_TT  Accessories    Tires and Tubes        true     2
# 291       CL_VE     Clothing              Vests       false    24
# 292       CL_VE     Clothing              Vests       false    24
# 293       CL_VE     Clothing              Vests       false    24
# 294       AC_BC  Accessories  Bottles and Cages       false     2
#
#     product_line start_date end_date         dwh_create_date
# 0           Road 2003-07-01      NaT 2025-05-25 15:28:04.543
# 1           Road 2003-07-01      NaT 2025-05-25 15:28:04.543
# 2       Mountain 2011-07-01      NaT 2025-05-25 15:28:04.543
# 3       Mountain 2011-07-01      NaT 2025-05-25 15:28:04.543
# 4       Mountain 2011-07-01      NaT 2025-05-25 15:28:04.543
# ..           ...        ...      ...                     ...
# 290      Touring 2013-07-01      NaT 2025-05-25 15:28:04.543
# 291  Other Sales 2013-07-01      NaT 2025-05-25 15:28:04.543
# 292  Other Sales 2013-07-01      NaT 2025-05-25 15:28:04.543
# 293  Other Sales 2013-07-01      NaT 2025-05-25 15:28:04.543
# 294  Other Sales 2013-07-01      NaT 2025-05-25 15:28:04.543
#
# [295 rows x 13 columns]

# %%
gold_fact_sales = con.execute("SELECT * FROM gold.fact_sales").df()
gold_fact_sales
# Out:
#       order_number  product_key  customer_key order_date shipping_date  \
# 0          SO43697           20         10769 2010-12-29    2011-01-05
# 1          SO43698            9         17390 2010-12-29    2011-01-05
# 2          SO43699            9         14864 2010-12-29    2011-01-05
# 3          SO43700           41          3502 2010-12-29    2011-01-05
# 4          SO43701            9             4 2010-12-29    2011-01-05
# ...            ...          ...           ...        ...           ...
# 60374      SO75122          174          4869 2014-01-28    2014-02-04
# 60375      SO75122          166          4869 2014-01-28    2014-02-04
# 60376      SO75123          174          7760 2014-01-28    2014-02-04
# 60377      SO75123          281          7760 2014-01-28    2014-02-04
# 60378      SO75123          166          7760 2014-01-28    2014-02-04
#
#         due_date  sales_amount  quantity  price         dwh_create_date
# 0     2011-01-10          3578         1   3578 2025-05-25 15:28:04.553
# 1     2011-01-10          3400         1   3400 2025-05-25 15:28:04.553
# 2     2011-01-10          3400         1   3400 2025-05-25 15:28:04.553
# 3     2011-01-10           699         1    699 2025-05-25 15:28:04.553
# 4     2011-01-10          3400         1   3400 2025-05-25 15:28:04.553
# ...          ...           ...       ...    ...                     ...
# 60374 2014-02-09            22         1     22 2025-05-25 15:28:04.553
# 60375 2014-02-09             9         1      9 2025-05-25 15:28:04.553
# 60376 2014-02-09            22         1     22 2025-05-25 15:28:04.553
# 60377 2014-02-09           159         1    159 2025-05-25 15:28:04.553
# 60378 2014-02-09             9         1      9 2025-05-25 15:28:04.553
#
# [60379 rows x 10 columns]

# %% [markdown]
# ### 2. Dimensions Exploration
#
# Dimensions are descriptive fields like customer name, product category, or region. Exploring dimensions means looking at the variety and frequency of these fields to uncover patterns.
#
# For example, you might check:
#
# - How many product categories exist
#
# - Which regions have the most sales
#
# - How customers are distributed by gender or age group

# %%
country_list = con.execute('SELECT DISTINCT country FROM gold.dim_customers').df()
country_list
# Out:
#           country
# 0  United Kingdom
# 1         Germany
# 2       Australia
# 3   United States
# 4          France
# 5          Canada
# 6             n/a

# %%
categories_list = con.execute('SELECT DISTINCT category, subcategory, product_name FROM gold.dim_products ORDER BY 1,2,3').df()
categories_list
# Out:
#         category        subcategory            product_name
# 0    Accessories         Bike Racks     Hitch Rack - 4-Bike
# 1    Accessories        Bike Stands  All-Purpose Bike Stand
# 2    Accessories  Bottles and Cages    Mountain Bottle Cage
# 3    Accessories  Bottles and Cages        Road Bottle Cage
# 4    Accessories  Bottles and Cages   Water Bottle - 30 oz.
# ..           ...                ...                     ...
# 290          n/a                n/a       LL Mountain Pedal
# 291          n/a                n/a           LL Road Pedal
# 292          n/a                n/a       ML Mountain Pedal
# 293          n/a                n/a           ML Road Pedal
# 294          n/a                n/a           Touring Pedal
#
# [295 rows x 3 columns]

# %% [markdown]
# ### 3. Date Exploration
#
# This focuses on understanding how data behaves over time. It includes identifying the date range of the dataset, spotting gaps in time, and understanding seasonality or trends.
#
# Key questions might be:
#
# - What is the time span of the dataset?
#
# - Are there missing days or months?
#
# - Is there a weekly/monthly/seasonal pattern?

# %%
date = con.execute("SELECT MIN(order_date) as first_order_date, MAX(order_date) as last_order_date, DATEDIFF('year', MIN(order_date), MAX(order_date)) as order_range_years FROM gold.fact_sales").df()
date
# Out:
#   first_order_date last_order_date  order_range_years
# 0       2010-12-29      2014-01-28                  4

# %%
date_customer = con.execute("SELECT MIN(birthdate) as oldest_birthdate, DATEDIFF('year', MIN(birthdate), current_date) as oldest_age, MIN(birthdate) as youngest_birthdate, DATEDIFF('year', MAX(birthdate), current_date) as youngest_age, FROM gold.dim_customers").df()
date_customer
# Out:
#   oldest_birthdate  oldest_age youngest_birthdate  youngest_age
# 0       1916-02-10         109         1916-02-10            39

# %% [markdown]
# ### 4. Measures Exploration
#
# Measures are numeric fields like sales, quantity, or profit. This step looks at how these numbers are distributed and helps detect outliers, trends, and data quality issues.

# %% [markdown]
# ##### Find the Total Sales

# %%
sales = con.execute("SELECT SUM(sales_amount) as total_sales from gold.fact_sales").df()
sales
# Out:
#    total_sales
# 0   29351258.0

# %% [markdown]
# ##### Find how many items are sold

# %%
sold = con.execute("SELECT SUM(quantity) as total_quantity from gold.fact_sales").df()
sold
# Out:
#    total_quantity
# 0         60404.0

# %% [markdown]
# ##### Find the Total number of Orders

# %%
orders = con.execute("SELECT COUNT(order_number) as total_orders FROM gold.fact_sales").df()
orders
# Out:
#    total_orders
# 0         60379

# %%
order_distinct = con.execute("SELECT COUNT(DISTINCT order_number) as total_orders FROM gold.fact_sales").df()
order_distinct
# Out:
#    total_orders
# 0         27657

# %% [markdown]
# ##### Find the Total number of Products

# %%
n_products = con.execute("SELECT COUNT(product_name) as total_orders FROM gold.dim_products").df()
n_products
# Out:
#    total_orders
# 0           295

# %%
n_products_distinct = con.execute("SELECT COUNT(DISTINCT product_name) as total_orders FROM gold.dim_products").df()
n_products_distinct
# Out:
#    total_orders
# 0           295

# %% [markdown]
# ##### Find the Total number of Customers

# %%
n_customers = con.execute("SELECT COUNT(customer_key) as total_customers FROM gold.dim_customers").df()
n_customers
# Out:
#    total_customers
# 0            18484

# %% [markdown]
# ##### Find the Total number of Customers that has place an order

# %%
n_customer_sales = con.execute("SELECT COUNT(customer_key) as total_customers FROM gold.fact_sales").df()
n_customer_sales
# Out:
#    total_customers
# 0            60379

# %%
n_customer_sales_distinct = con.execute("SELECT COUNT(DISTINCT customer_key) as total_customers FROM gold.fact_sales").df()
n_customer_sales_distinct
# Out:
#    total_customers
# 0            18482

# %% [markdown]
# ##### Generate a Report that shows all key metrics of the business

# %%
report = con.execute("""
SELECT 'Total Sales' AS measure_name, PRINTF('%.2f', CAST(SUM(sales_amount) AS DOUBLE)) AS measure_value FROM gold.fact_sales
UNION ALL
SELECT 'Total Quantity', PRINTF('%.0f', CAST(SUM(quantity) AS DOUBLE)) FROM gold.fact_sales
UNION ALL
SELECT 'Average Price', PRINTF('%.2f', CAST(AVG(price) AS DOUBLE)) FROM gold.fact_sales
UNION ALL
SELECT 'Total no. Orders', PRINTF('%.0f', CAST(COUNT(DISTINCT order_number) AS DOUBLE)) FROM gold.fact_sales
UNION ALL
SELECT 'Total no. Products', PRINTF('%.0f', CAST(COUNT(product_name) AS DOUBLE)) FROM gold.dim_products
UNION ALL
SELECT 'Total no. Customers', PRINTF('%.0f', CAST(COUNT(customer_key) AS DOUBLE)) FROM gold.dim_customers
""").df()

report
# Out:
#           measure_name measure_value
# 0          Total Sales   29351258.00
# 1       Total Quantity         60404
# 2        Average Price        486.11
# 3     Total no. Orders         27657
# 4   Total no. Products           295
# 5  Total no. Customers         18484

# %% [markdown]
# ### 5. Magnitude Analysis
#
# This analysis tells you how much of something exists. It shows the scale of values in your data, helping you understand volume and size.

# %% [markdown]
# ##### Find total customers by countries

# %%
n_customer_by_country = con.execute("SELECT COUNT(customer_id), country FROM gold.dim_customers GROUP BY country").df()
n_customer_by_country
# Out:
#    count(customer_id)         country
# 0                1571          Canada
# 1                 337             n/a
# 2                1780         Germany
# 3                1810          France
# 4                1913  United Kingdom
# 5                3591       Australia
# 6                7482   United States

# %% [markdown]
# ##### Find total customers by gender

# %%
n_customer_by_gender = con.execute("SELECT COUNT(customer_id) as total_customers, gender FROM gold.dim_customers GROUP BY gender ORDER BY total_customers DESC").df()
n_customer_by_gender
# Out:
#    total_customers  gender
# 0             9341    Male
# 1             9128  Female
# 2               15     n/a

# %% [markdown]
# ##### Find total products by category

# %%
n_products_by_category = con.execute("SELECT COUNT(product_id) as total_products, category FROM gold.dim_products GROUP BY category ORDER BY total_products DESC").df()
n_products_by_category
# Out:
#    total_products     category
# 0             127   Components
# 1              97        Bikes
# 2              35     Clothing
# 3              29  Accessories
# 4               7          n/a

# %% [markdown]
# ##### What is  the average costs in each category?

# %%
avg_cost_country = con.execute("SELECT category, AVG(cost) as avg_costs FROM gold.dim_products GROUP BY category ORDER BY avg_costs DESC").df()
avg_cost_country
# Out:
#       category   avg_costs
# 0        Bikes  949.443299
# 1   Components  264.716535
# 2          n/a   28.571429
# 3     Clothing   24.800000
# 4  Accessories   13.172414

# %% [markdown]
# ##### What is the total revenue generated for each category

# %%
total_revenue_by_category = con.execute("SELECT p.category, SUM(f.sales_amount) as total_revenue FROM gold.fact_sales f LEFT JOIN gold.dim_products p on f.product_key = p.product_key GROUP BY p.category ORDER BY total_revenue DESC").df()
total_revenue_by_category
# Out:
#       category  total_revenue
# 0        Bikes     28311657.0
# 1  Accessories       699909.0
# 2     Clothing       339692.0

# %% [markdown]
# ##### Find total revenue is generated by each customer

# %%
total_revenue_customer = con.execute("SELECT c.customer_key, c.first_name, c.last_name, SUM(f.sales_amount) as total_revenue FROM gold.fact_sales f LEFT JOIN gold.dim_customers c on c.customer_key = f.customer_key GROUP BY c.customer_key, c.first_name, c.last_name ORDER BY total_revenue DESC").df()
total_revenue_customer
# Out:
#        customer_key first_name  last_name  total_revenue
# 0              1133    Kaitlyn  Henderson        13294.0
# 1              1302    Nichole       Nara        13294.0
# 2              1309   Margaret         He        13268.0
# 3              1132    Randall  Dominguez        13265.0
# 4              1301    Adriana   Gonzalez        13242.0
# ...             ...        ...        ...            ...
# 18477         17301    Abigail    Bennett            2.0
# 18478         17969     Marcus     Morgan            2.0
# 18479         16994     Hunter     Miller            2.0
# 18480         17095    Melanie   Peterson            2.0
# 18481         16992    Natalie     Rivera            2.0
#
# [18482 rows x 4 columns]

# %% [markdown]
# ##### What is the distribution of sold items across countries ?

# %%
distribution_items_countries = con.execute("SELECT c.country, SUM(f.quantity) as total_sold_items FROM gold.fact_sales f LEFT JOIN gold.dim_customers c ON f.customer_key = c.customer_key GROUP BY c.country ORDER BY total_sold_items DESC").df()
distribution_items_countries
# Out:
#           country  total_sold_items
# 0   United States           20474.0
# 1       Australia           13344.0
# 2          Canada            7629.0
# 3  United Kingdom            6908.0
# 4         Germany            5626.0
# 5          France            5552.0
# 6             n/a             871.0

# %% [markdown]
# ### 6. Ranking Analysis
#
# Ranking helps identify top or bottom performers based on a metric.

# %% [markdown]
# ##### Which 5 products generate the highest revenue ?

# %%
products_generate_rank = con.execute("SELECT * FROM (SELECT p.product_name, SUM(f.sales_amount) as total_revvenue, RANK() OVER (ORDER BY SUM(f.sales_amount) DESC) as rank_products FROM gold.fact_sales f LEFT JOIN gold.dim_products p ON f.product_key = p.product_key GROUP BY p.product_name) t WHERE rank_products <= 5").df()
products_generate_rank
# Out:
#               product_name  total_revvenue  rank_products
# 0   Mountain-200 Black- 46       1373454.0              1
# 1   Mountain-200 Black- 42       1363128.0              2
# 2  Mountain-200 Silver- 38       1339394.0              3
# 3  Mountain-200 Silver- 46       1298709.0              4
# 4   Mountain-200 Black- 38       1292559.0              5

# %% [markdown]
# ##### What are the 5 worst performing products in terms of sales ?

# %%
worst_perform = con.execute("SELECT c.customer_key, c.first_name, c.last_name, COUNT(DISTINCT order_number) as total_orders FROM gold.fact_sales f LEFT JOIN gold.dim_customers c ON f.customer_key = c.customer_key GROUP BY c.customer_key, c.first_name, c.last_name ORDER BY total_orders LIMIT 10").df()
worst_perform
# Out:
#    customer_key  first_name last_name  total_orders
# 0          2400      Edward     Young             1
# 1          5284     Clayton      Raji             1
# 2          2468  Kristopher  Martinez             1
# 3          5786   Christian       Lee             1
# 4          6725      Sheila    Blanco             1
# 5          1797       Jason     Zhang             1
# 6          7899      Monica   Chandra             1
# 7           510       Roger     Harui             1
# 8          6615       Mason      Cook             1
# 9          8555    Emmanuel     Raman             1

# %% [markdown]
# ## Data & Report Analysis

# %% [markdown]
# ### 7. Change Over Time
#
# This analysis focuses on how metrics evolve over a period. It highlights trends, spikes, or declines.

# %%
change_over_time = con.execute("""
SELECT
strftime(order_date, '%Y-%b') as order_date,
SUM(sales_amount) as total_sales,
COUNT(DISTINCT customer_key) as total_customers,
SUM(quantity) as total_quantity
FROM gold.fact_sales
WHERE order_date IS NOT NULL
GROUP BY strftime(order_date, '%Y-%b')
ORDER BY strftime(order_date, '%Y-%b')
""").df()
change_over_time
# Out:
#    order_date  total_sales  total_customers  total_quantity
# 0    2010-Dec      43419.0               14            14.0
# 1    2011-Apr     502042.0              157           157.0
# 2    2011-Aug     614516.0              193           193.0
# 3    2011-Dec     669395.0              222           222.0
# 4    2011-Feb     466307.0              144           144.0
# 5    2011-Jan     469795.0              144           144.0
# 6    2011-Jul     596710.0              188           188.0
# 7    2011-Jun     737793.0              230           230.0
# 8    2011-Mar     485165.0              150           150.0
# 9    2011-May     561647.0              174           174.0
# 10   2011-Nov     660507.0              208           208.0
# 11   2011-Oct     708164.0              221           221.0
# 12   2011-Sep     603047.0              185           185.0
# 13   2012-Apr     400324.0              219           219.0
# 14   2012-Aug     523887.0              294           294.0
# 15   2012-Dec     624454.0              354           483.0
# 16   2012-Feb     506992.0              260           260.0
# 17   2012-Jan     495363.0              252           252.0
# 18   2012-Jul     444533.0              246           246.0
# 19   2012-Jun     555142.0              318           318.0
# 20   2012-Mar     373478.0              212           212.0
# 21   2012-May     358866.0              207           207.0
# 22   2012-Nov     537918.0              324           324.0
# 23   2012-Oct     535125.0              313           313.0
# 24   2012-Sep     486149.0              269           269.0
# 25   2013-Apr    1045860.0             1564          3979.0
# 26   2013-Aug    1545910.0             1898          4848.0
# 27   2013-Dec    1874128.0             2133          5520.0
# 28   2013-Feb     771218.0             1373          3454.0
# 29   2013-Jan     857758.0              627          1677.0
# 30   2013-Jul    1371595.0             1796          4673.0
# 31   2013-Jun    1642948.0             1948          5025.0
# 32   2013-Mar    1049732.0             1631          4087.0
# 33   2013-May    1284456.0             1719          4400.0
# 34   2013-Nov    1780688.0             2036          5224.0
# 35   2013-Oct    1673261.0             2073          5304.0
# 36   2013-Sep    1447324.0             1832          4616.0
# 37   2014-Jan      45642.0              834          1970.0

# %% [markdown]
# ### 8. Cumulative Analysis
#
# Here, you look at how values accumulate over time. It's great for understanding long-term trends and growth.

# %%
cumulative_analysis = con.execute("""
SELECT 
    order_date,
    total_sales,
    SUM(total_sales) OVER (ORDER BY order_date) AS running_total_sales,
    avg_price,
    avg(avg_price) OVER (ORDER BY order_date) AS moving_average
    FROM
        (
            SELECT
                DATETRUNC ('month', order_date) AS order_date,
                SUM(sales_amount) AS total_sales,
                AVG(price) as avg_price
                FROM gold. fact_sales
                WHERE order_date IS NOT NULL
                GROUP BY DATETRUNC ('month', order_date)
        ) t
""").df()
cumulative_analysis
# Out:
#    order_date  total_sales  running_total_sales    avg_price  moving_average
# 0  2010-12-01      43419.0              43419.0  3101.357143     3101.357143
# 1  2011-01-01     469795.0             513214.0  3262.465278     3181.911210
# 2  2011-02-01     466307.0             979521.0  3238.243056     3200.688492
# 3  2011-03-01     485165.0            1464686.0  3234.433333     3209.124702
# 4  2011-04-01     502042.0            1966728.0  3197.719745     3206.843711
# 5  2011-05-01     561647.0            2528375.0  3227.856322     3210.345813
# 6  2011-06-01     737793.0            3266168.0  3207.795652     3209.981504
# 7  2011-07-01     596710.0            3862878.0  3173.989362     3205.482486
# 8  2011-08-01     614516.0            4477394.0  3184.020725     3203.097846
# 9  2011-09-01     603047.0            5080441.0  3259.713514     3208.759413
# 10 2011-10-01     708164.0            5788605.0  3204.361991     3208.359647
# 11 2011-11-01     660507.0            6449112.0  3175.514423     3205.622545
# 12 2011-12-01     669395.0            7118507.0  3015.292793     3190.981795
# 13 2012-01-01     495363.0            7613870.0  1965.726190     3103.463538
# 14 2012-02-01     506992.0            8120862.0  1949.969231     3026.563917
# 15 2012-03-01     373478.0            8494340.0  1761.688679     2947.509215
# 16 2012-04-01     400324.0            8894664.0  1827.963470     2881.653583
# 17 2012-05-01     358866.0            9253530.0  1733.652174     2817.875727
# 18 2012-06-01     555142.0            9808672.0  1745.729560     2761.446981
# 19 2012-07-01     444533.0           10253205.0  1807.044715     2713.726868
# 20 2012-08-01     523887.0           10777092.0  1781.928571     2669.355520
# 21 2012-09-01     486149.0           11263241.0  1807.245353     2630.168695
# 22 2012-10-01     535125.0           11798366.0  1709.664537     2590.146775
# 23 2012-11-01     537918.0           12336284.0  1660.240741     2551.400690
# 24 2012-12-01     624454.0           12960738.0  1292.865424     2501.059279
# 25 2013-01-01     857758.0           13818496.0   516.009627     2424.711216
# 26 2013-02-01     771218.0           14589714.0   223.344917     2343.179131
# 27 2013-03-01    1049732.0           15639446.0   256.846587     2268.667254
# 28 2013-04-01    1045860.0           16685306.0   262.844936     2199.500967
# 29 2013-05-01    1284456.0           17969762.0   291.980223     2135.916942
# 30 2013-06-01    1642948.0           19612710.0   326.954826     2077.563326
# 31 2013-07-01    1371595.0           20984305.0   293.619139     2021.815070
# 32 2013-08-01    1545910.0           22530215.0   318.875825     1970.210850
# 33 2013-09-01    1447324.0           23977539.0   313.545061     1921.485386
# 34 2013-10-01    1673261.0           25650800.0   315.782182     1875.608152
# 35 2013-11-01    1780688.0           27431488.0   340.866769     1832.976447
# 36 2013-12-01    1874128.0           29305616.0   339.515942     1792.612649
# 37 2014-01-01      45642.0           29351258.0    23.168528     1746.048330

# %% [markdown]
# ### 9. Performance Analysis
#
# Performance analysis evaluates how well something is doing compared to expectations or benchmarks.

# %%
performance_analysis = con.execute("""
WITH yearly_product_sales AS (
    SELECT 
    YEAR(f.order_date) as order_year,
    p.product_name,
    SUM(f.sales_amount) as current_sales
    FROM gold.fact_sales f 
    LEFT JOIN gold.dim_products p ON f.product_key = p.product_key 
    WHERE f.order_date IS NOT NULL
    GROUP BY YEAR(f.order_date), p.product_name
)

SELECT
    order_year, 
    product_name,
    current_sales,
    
    -- Average sales per product
    AVG(current_sales) OVER (PARTITION BY product_name) AS avg_sales,
    
    -- Difference from average
    current_sales - AVG(current_sales) OVER (PARTITION BY product_name) AS diff_avg,
    
    -- Above/Below/Average classification
    CASE
        WHEN current_sales > AVG(current_sales) OVER (PARTITION BY product_name) THEN 'Above Avg'
        WHEN current_sales < AVG(current_sales) OVER (PARTITION BY product_name) THEN 'Below Avg'
        ELSE 'Avg'
    END AS avg_change,
    
    -- Prior year sales
    LAG(current_sales) OVER (PARTITION BY product_name ORDER BY order_year) AS py_sales,
    
    -- Difference from prior year
    current_sales - LAG(current_sales) OVER (PARTITION BY product_name ORDER BY order_year) AS diff_py,
    
    -- Prior year change label
    CASE
        WHEN current_sales > LAG(current_sales) OVER (PARTITION BY product_name ORDER BY order_year) THEN 'Increase'
        WHEN current_sales < LAG(current_sales) OVER (PARTITION BY product_name ORDER BY order_year) THEN 'Decrease'
        ELSE 'No Change'
    END AS py_change

FROM yearly_product_sales
ORDER BY product_name, order_year;
""").df()
performance_analysis
# Out:
#      order_year                product_name  current_sales  avg_sales  \
# 0          2012                AWC Logo Cap           72.0     6570.0
# 1          2013                AWC Logo Cap        18891.0     6570.0
# 2          2014                AWC Logo Cap          747.0     6570.0
# 3          2012      All-Purpose Bike Stand          159.0    13197.0
# 4          2013      All-Purpose Bike Stand        37683.0    13197.0
# ..          ...                         ...            ...        ...
# 266        2014  Women's Mountain Shorts- L         1610.0    12705.0
# 267        2013  Women's Mountain Shorts- M        23380.0    12320.0
# 268        2014  Women's Mountain Shorts- M         1260.0    12320.0
# 269        2013  Women's Mountain Shorts- S        20230.0    10640.0
# 270        2014  Women's Mountain Shorts- S         1050.0    10640.0
#
#      diff_avg avg_change  py_sales  diff_py  py_change
# 0     -6498.0  Below Avg       NaN      NaN  No Change
# 1     12321.0  Above Avg      72.0  18819.0   Increase
# 2     -5823.0  Below Avg   18891.0 -18144.0   Decrease
# 3    -13038.0  Below Avg       NaN      NaN  No Change
# 4     24486.0  Above Avg     159.0  37524.0   Increase
# ..        ...        ...       ...      ...        ...
# 266  -11095.0  Below Avg   23800.0 -22190.0   Decrease
# 267   11060.0  Above Avg       NaN      NaN  No Change
# 268  -11060.0  Below Avg   23380.0 -22120.0   Decrease
# 269    9590.0  Above Avg       NaN      NaN  No Change
# 270   -9590.0  Below Avg   20230.0 -19180.0   Decrease
#
# [271 rows x 9 columns]

# %% [markdown]
# ### 10. Part to Whole Propotional
#
# This analysis shows how individual pieces contribute to the total. It’s often visualized using pie charts or percentage bars.

# %%
propotional = con.execute("""
    WITH category_sales as (SELECT category, SUM(sales_amount) total_sales FROM gold.fact_sales f LEFT JOIN gold.dim_products p ON f.product_key = p.product_key GROUP BY category)
                          
    SELECT 
        category,
        total_sales,
        SUM(total_sales) OVER () AS overall_sales,
        CONCAT(
            ROUND((CAST(total_sales AS FLOAT) / SUM(total_sales) OVER ()) * 100, 2),
            '%'
        ) AS percentage_of_total
    FROM category_sales;
""").df()
propotional
# Out:
#       category  total_sales  overall_sales percentage_of_total
# 0        Bikes   28311657.0     29351258.0              96.46%
# 1     Clothing     339692.0     29351258.0               1.16%
# 2  Accessories     699909.0     29351258.0               2.38%

# %% [markdown]
# ### 11. Data Segmentation
#
# Segmentation means splitting your data into meaningful groups to analyze behavior or performance within each group.

# %%
data_segmentation = con.execute("""
    with customer_spending AS (
        SELECT
        c.customer_key,
        SUM(f.sales_amount) AS total_spending,
        MIN(order_date) AS first_order,
        MAX(order_date) AS last_order,
        DATEDIFF ('month', MIN(order_date), MAX(order_date)) AS lifespan
        FROM gold.fact_sales f
        LEFT JOIN gold.dim_customers c
        ON f.customer_key = c.customer_key
        GROUP BY c.customer_key
    )
                                
    SELECT
    customer_segment,
    COUNT (customer_key) as customer_key
    FROM (
        SELECT
            customer_key,
            CASE WHEN lifespan >= 12 AND total_spending > 5000 THEN 'VIP'
            WHEN lifespan >= 12 AND total_spending <= 5000 THEN 'Regular' ELSE 'New'
            END customer_segment
            FROM customer_spending
    ) t
    GROUP BY customer_segment
    ORDER BY customer_key DESC
""").df()
data_segmentation
# Out:
#   customer_segment  customer_key
# 0              New         14629
# 1          Regular          2200
# 2              VIP          1653

# %% [markdown]
# ### 12. Reporting
#
# Reporting brings together all analyses into readable summaries for decision-making. It combines visuals, KPIs, and insights to give a clear view of business performance.
#
# Purpose: This report consolidates key customer metrics and behaviors
#
#
# Highlights:
# 1. Gathers essential fields such as names, ages, and transaction details.
# 2. Segments customers into categories (VIP, Regular, New) and age groups.
# 3. Aggregates customer-level metrics:
#     - total orders
#     - total sales
#     - total quantity purchased
#     - total products
#     - lifespan (in months)
# 4. Calculates valuable KPIs:
#     - recency (months since last order)
#     - average order value
#     - average monthly spend

# %%
reporting_customer = con.execute("""
CREATE VIEW IF NOT EXISTS gold.report_customer AS
WITH base_query AS (
    SELECT 
        f.order_number,
        f.product_key,
        f.order_date, 
        f.sales_amount, 
        f.quantity, 
        c.customer_key, 
        c.customer_number, 
        CONCAT(c.first_name,' ',c.last_name) as customer_name,
        DATEDIFF('year', c.birthdate, current_date) as age
        FROM gold.fact_sales f 
        LEFT JOIN gold.dim_customers c 
        ON f.customer_key = c.customer_key 
        WHERE order_date IS NOT NULL                        
),
customer_aggregation as (
    SELECT 
        customer_key, 
        customer_number, 
        customer_name,
        age,
        COUNT (DISTINCT order_number) as total_orders,
        SUM(sales_amount) as total_sales,
        SUM(quantity) as total_quantity,
        COUNT (DISTINCT product_key) as total_products,
        MAX(order_date) as last_order_date,
        DATEDIFF('month', MIN(order_date), MAX(order_date)) as lifespan
        FROM base_query
        GROUP BY customer_key, customer_number, customer_name, age
)           

SELECT
    customer_key,
    customer_number,
    customer_name,
    age,
    CASE
        WHEN age < 20 THEN 'Under 20'
        WHEN age between 20 and 29 THEN '20-29' 
        WHEN age between 30 and 39 THEN '30-39'
        WHEN age between 40 and 49 THEN '40-49' 
        ELSE '50 and above'
    END AS age_group,
    CASE
        WHEN lifespan >= 12 AND total_sales > 5000 THEN 'VIP'
        WHEN lifespan >= 12 AND total_sales <= 5000 THEN 'Regular' 
        ELSE 'New'
    END AS customer_segment,
    last_order_date,
    DATEDIFF ('month', last_order_date, current_date) as recency,
    total_orders,
    total_sales,
    total_quantity,
    total_products,
    lifespan,
    CASE 
        WHEN total_orders = 0 THEN 0 
        ELSE total_sales / total_orders 
    END AS avg_order_value,
    CASE
        WHEN lifespan = 0 THEN total_sales
        ELSE total_sales / lifespan
    END AS avg_monthly_spend
    FROM customer_aggregation

          
""")
# Out:
# Empty DataFrame
# Columns: [Count]
# Index: []

# %% [markdown]
# Product Report
#
# Purpose:
# This report consolidates key product metrics and behaviors.
# Highlights:
# 1. Gathers essential fields such as product name, category, subcategory, and cost
# 2. Segments products by revenue to identify High-Performers, Mid-Range, or Low-Performers
# 3. Aggregates product-level metrics:
#     - total orders
#     - total sales
#     - total quantity sold
#     - total customers (unique)
#     - lifespan (in months)
# 4. Calculates valuable KPIs:
#     - recency (months since last sale)
#     - average order revenue (AOR)
#     - average monthly revenue

# %%
reporting_products = con.execute("""

CREATE VIEW gold.report_products AS
WITH base_query AS (
    SELECT
        f.order_number,
        f.order_date,
        f.customer_key,
        f.sales_amount,
        f.quantity,
        p.product_key, 
        p.product_name,
        p.category,
        p.subcategory,                   
        p.cost
    FROM gold.fact_sales f
    LEFT JOIN gold.dim_products p
        ON f.product_key = p.product_key
    WHERE order_date IS NOT NULL                           
),
product_aggregations AS (
    SELECT
        product_key, 
        product_name, 
        category,
        subcategory,
        cost,
        DATEDIFF('month', MIN(order_date), MAX(order_date)) AS lifespan,
        MAX(order_date) AS last_sale_date,
        COUNT(DISTINCT order_number) AS total_orders,
        COUNT(DISTINCT customer_key) AS total_customers,
        SUM(sales_amount) AS total_sales,
        SUM(quantity) AS total_quantity,
        ROUND(
            AVG(CAST(sales_amount AS FLOAT) / NULLIF(quantity, 0)),
            1
        ) AS avg_selling_price
    FROM base_query
    GROUP BY
        product_key,
        product_name,
        category,
        subcategory,
        cost
)
SELECT
    product_key,
    product_name, 
    category,
    subcategory,
    cost,
    last_sale_date,
    DATEDIFF('month', last_sale_date, CURRENT_DATE) AS recency_in_months,
    CASE
        WHEN total_sales > 50000 THEN 'High-Performer'
        WHEN total_sales >= 10000 THEN 'Mid-Range'
        ELSE 'Low-Performer'
    END AS product_segment,
    lifespan,
    total_orders,
    total_sales,
    total_quantity,
    total_customers,
    avg_selling_price,
    CASE
        WHEN lifespan = 0 THEN total_sales
        ELSE total_sales / lifespan
    END AS avg_monthly_revenue
FROM product_aggregations

""")

# %%
report_cus = con.execute("SELECT * FROM gold.report_customer").df()
report_cus
# Out:
#        customer_key customer_number   customer_name  age     age_group  \
# 0                 2      AW00011001    Eugene Huang   49         40-49
# 1                14      AW00011013     Ian Jenkins   46         40-49
# 2                17      AW00011016      Wyatt Hill   41         40-49
# 3                40      AW00011039     Marc Martin   71  50 and above
# 4                61      AW00011060        Jon Zhou   66  50 and above
# ...             ...             ...             ...  ...           ...
# 18477         18405      AW00029404      Chloe Ross   51  50 and above
# 18478         18406      AW00029405    Meagan Vance   42         40-49
# 18479         18422      AW00029421  Blake Williams   44         40-49
# 18480         18452      AW00029451  Geoffrey Lopez   66  50 and above
# 18481         18460      AW00029459  Marco Malhotra   43         40-49
#
#       customer_segment last_order_date  recency  total_orders  total_sales  \
# 0                  VIP      2013-12-10      137             3       6384.0
# 1                  New      2014-01-21      136             2        114.0
# 2                  New      2013-02-09      147             1       2332.0
# 3                  VIP      2013-11-11      138             3       6636.0
# 4                  VIP      2013-06-25      143             3       8153.0
# ...                ...             ...      ...           ...          ...
# 18477              New      2012-08-05      153             1       2049.0
# 18478              New      2013-08-13      141             1         54.0
# 18479              New      2013-12-02      137             1         78.0
# 18480              New      2013-02-08      147             1         25.0
# 18481              New      2013-09-19      140             1        805.0
#
#        total_quantity  total_products  lifespan  avg_order_value  \
# 0                11.0              10        35      2128.000000
# 1                 5.0               5         9        57.000000
# 2                 3.0               3         0      2332.000000
# 3                 9.0               8        33      2212.000000
# 4                 6.0               6        27      2717.666667
# ...               ...             ...       ...              ...
# 18477             1.0               1         0      2049.000000
# 18478             1.0               1         0        54.000000
# 18479             2.0               2         0        78.000000
# 18480             2.0               2         0        25.000000
# 18481             3.0               3         0       805.000000
#
#        avg_monthly_spend
# 0             182.400000
# 1              12.666667
# 2            2332.000000
# 3             201.090909
# 4             301.962963
# ...                  ...
# 18477        2049.000000
# 18478          54.000000
# 18479          78.000000
# 18480          25.000000
# 18481         805.000000
#
# [18482 rows x 15 columns]

# %%
report_prod = con.execute("SELECT * FROM gold.report_products").df()
report_prod
# Out:
#      product_key                    product_name     category  \
# 0            287                    HL Road Tire  Accessories
# 1            113         Mountain-500 Silver- 44        Bikes
# 2            277  Short-Sleeve Classic Jersey- S     Clothing
# 3            294                 Classic Vest- S     Clothing
# 4            272      Women's Mountain Shorts- L     Clothing
# ..           ...                             ...          ...
# 125          126              Road-750 Black- 44        Bikes
# 126          250      Long-Sleeve Logo Jersey- S     Clothing
# 127          293                 Classic Vest- M     Clothing
# 128          119       Mountain-400-W Silver- 46        Bikes
# 129          273      Women's Mountain Shorts- M     Clothing
#
#          subcategory  cost last_sale_date  recency_in_months product_segment  \
# 0    Tires and Tubes    12     2014-01-28                136       Mid-Range
# 1     Mountain Bikes   308     2013-12-25                137       Mid-Range
# 2            Jerseys    42     2014-01-28                136       Mid-Range
# 3              Vests    24     2014-01-28                136       Mid-Range
# 4             Shorts    26     2014-01-28                136       Mid-Range
# ..               ...   ...            ...                ...             ...
# 125       Road Bikes   344     2013-12-28                137  High-Performer
# 126          Jerseys    38     2014-01-28                136       Mid-Range
# 127            Vests    24     2014-01-27                136       Mid-Range
# 128   Mountain Bikes   420     2013-12-24                137  High-Performer
# 129           Shorts    26     2014-01-26                136       Mid-Range
#
#      lifespan  total_orders  total_sales  total_quantity  total_customers  \
# 0          13           858      28314.0           858.0              820
# 1          12            39      22035.0            39.0               39
# 2          13           406      21924.0           406.0              402
# 3          13           168      10944.0           171.0              168
# 4          12           363      25410.0           363.0              363
# ..        ...           ...          ...             ...              ...
# 125        12           360     194400.0           360.0              360
# 126        12           429      21450.0           429.0              426
# 127        12           199      12736.0           199.0              199
# 128        11           138     106122.0           138.0              138
# 129        12           352      24640.0           352.0              352
#
#      avg_selling_price  avg_monthly_revenue
# 0                 33.0          2178.000000
# 1                565.0          1836.250000
# 2                 54.0          1686.461538
# 3                 64.0           841.846154
# 4                 70.0          2117.500000
# ..                 ...                  ...
# 125              540.0         16200.000000
# 126               50.0          1787.500000
# 127               64.0          1061.333333
# 128              769.0          9647.454545
# 129               70.0          2053.333333
#
# [130 rows x 15 columns]
